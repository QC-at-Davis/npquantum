# %%
import numpy as np
from qiskit import(
  QuantumCircuit,
  execute,
  Aer)
from qiskit.visualization import plot_bloch_multivector

# %%
# Use Aer's qasm_simulator
#simulator = Aer.get_backend('qasm_simulator')
backend = Aer.get_backend('statevector_simulator')

# %% [markdown]
# ## $\frac{\pi}{8}$ rotation

# %%
#Create a Quantum Circuit acting on the q register
circuit = QuantumCircuit(1,1)

# %%
# Phase rotation
circuit.h(0)
circuit.rz(np.pi/8,0)

# %%
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)

# %%
plot_bloch_multivector(psi)

# %%
# use the hadamard to get out of phase space
circuit.h(0)

# %%
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)

# %%
plot_bloch_multivector(psi)

# %% [markdown]
# ## $\frac{\pi}{4}$ rotation

# %%
circuit = QuantumCircuit(1,1)
circuit.h(0)
circuit.rz(np.pi/4,0)
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)
plot_bloch_multivector(psi)

# %%
# use the hadamard to get out of phase space
circuit.h(0)
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)
plot_bloch_multivector(psi)

# %% [markdown]
# ## $\frac{3\pi}{2}$ rotation

# %%
circuit = QuantumCircuit(1,1)
circuit.h(0)
circuit.rz(3*np.pi/2,0)
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)
plot_bloch_multivector(psi)

# %%
circuit.h(0)
circuit.draw('mpl')

# %%
result = execute(circuit, backend).result()
psi  = result.get_statevector(circuit)
plot_bloch_multivector(psi)

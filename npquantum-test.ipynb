# %%
from importlib import reload  
import numpy as np
import npquantum as npq
from qiskit.visualization import plot_bloch_multivector

# %%
npq = reload(npq)

# %%
npq.ket10
# Out:
# matrix([[0],
#         [0],
#         [1],
#         [0]])

# %%
npq.SWAP * npq.ket10
# Out:
# matrix([[0],
#         [1],
#         [0],
#         [0]])

# %%
npq.ket01
# Out:
# matrix([[0],
#         [1],
#         [0],
#         [0]])

# %%
npq.pauli_x
# Out:
# matrix([[0, 1],
#         [1, 0]])

# %%
npq.X
# Out:
# matrix([[0, 1],
#         [1, 0]])

# %%
npq.X * npq.X.H
# Out:
# matrix([[1, 0],
#         [0, 1]])

# %%
npq.T * npq.T.H
# Out:
# matrix([[1.+0.j, 0.+0.j],
#         [0.+0.j, 1.+0.j]])

# %%
npq.I
# Out:
# matrix([[1., 0.],
#         [0., 1.]])

# %%
npq.pauli_x
# Out:
# matrix([[0, 1],
#         [1, 0]])

# %%
npq.pauli_y
# Out:
# matrix([[ 0.+0.j, -0.-1.j],
#         [ 0.+1.j,  0.+0.j]])

# %%
npq.pauli_z * npq.pauli_z.H
# Out:
# matrix([[1, 0],
#         [0, 1]])

# %%
plot_bloch_multivector(npq.to_qiskit_plot(npq.ket_from_angles(np.pi/3, np.pi/2)))

# %%
from npquantum import *

# %%
class IonTrap:
    Rx = Rx
    Ry = Ry
    Rz = Rz

# %%
IonTrap.Rx
# Out:
# <function npquantum.Rx(theta)>
